# %% [markdown]
# # DS 2010 Final Project - Regression

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
import statistics
import json
import statsmodels.api as sm

# %% [markdown]
# ## Import Data

# %%
# set random seed
np.random.seed(2010) 

# import data 
data = pd.read_csv("Clean_Data/final_data.csv")
responses = ['Mix_Score', 'Depression_Score', 'Anxiety_Score']

# %% [markdown]
# ## Multiple Linear Regression

# %%
def multiple_linear_regression(data, predictors, responses):
    for response in responses:
        X = data.loc[:,predictors] # feature columns
        y = data.loc[:,response] # label column

        ## Linear Regression ##
        regr = linear_model.LinearRegression()
        lm = regr.fit(X, y) # train on training data
        score = regr.score(X, y)

        # Create summary table
        X2 = sm.add_constant(X)
        est = sm.OLS(y, X2)
        est2 = est.fit()
        
        print(est2.summary())
        # print(regr.coef_)
        print(score)

# %% [markdown]
# ### Run on all data

# %%
# Multiple Linear Regression
# All Data
all_data = data.copy()

# ignore_columns = ['Period', 'state','positiveTestsViral', 'positiveTestsViralIncrease']
# drop_by_columns = [item for item in list(new_england.columns) if item not in ignore_columns]
feature_data = all_data.drop(['death', 'positiveTestsViral', 'positiveTestsViralIncrease',
                              'positivityRate', 'positiveCasesViral'],
                               axis= 1)

predictors = feature_data.columns[5:]
multiple_linear_regression(feature_data, predictors, responses)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Mix_Score   R-squared:                       0.299
# Model:                            OLS   Adj. R-squared:                  0.286
# Method:                 Least Squares   F-statistic:                     23.80
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           6.71e-55
# Time:                        03:49:31   Log-Likelihood:                -2349.5
# No. Observations:                 853   AIC:                             4731.
# Df Residuals:                     837   BIC:                             4807.
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                            -22.6711     11.418     -1.986      0.047     -45.082      -0.260
# deathIncrease                  -5.399e+05   8.86e+04     -6.094      0.000   -7.14e+05   -3.66e+05
# hospitalizedCurrently           2.096e+04   2782.808      7.533      0.000    1.55e+04    2.64e+04
# positiveCasesIncrease            -57.3842     95.910     -0.598      0.550    -245.636     130.867
# Population Staying at Home        43.6511      6.264      6.969      0.000      31.357      55.945
# Population Not Staying at Home    29.7924      5.975      4.986      0.000      18.065      41.520
# Number of Trips                    3.1769      5.162      0.615      0.538      -6.955      13.309
# Number of Trips <1                -7.0369      5.361     -1.313      0.190     -17.559       3.485
# Number of Trips 1-3               -3.8696      5.639     -0.686      0.493     -14.939       7.200
# Number of Trips 3-5               -8.8615      7.123     -1.244      0.214     -22.842       5.119
# Number of Trips 5-10               7.0603      6.999      1.009      0.313      -6.677      20.798
# Number of Trips 10-25             -5.6720      5.280     -1.074      0.283     -16.036       4.692
# Number of Trips 25-50            -13.6231      7.479     -1.822      0.069     -28.302       1.056
# Number of Trips 50-100             2.7921     10.207      0.274      0.785     -17.243      22.827
# Number of Trips 100-250          -53.8720     20.848     -2.584      0.010     -94.793     -12.951
# Number of Trips 250-500          228.4196     60.322      3.787      0.000     110.019     346.820
# Number of Trips >=500           -142.1598     55.812     -2.547      0.011    -251.708     -32.612
# ==============================================================================
# Omnibus:                        4.994   Durbin-Watson:                   1.223
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                5.298
# Skew:                           0.117   Prob(JB):                       0.0707
# Kurtosis:                       3.307   Cond. No.                     2.09e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.55e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.2994319139713775
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Depression_Score   R-squared:                       0.269
# Model:                            OLS   Adj. R-squared:                  0.256
# Method:                 Least Squares   F-statistic:                     20.55
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           1.30e-47
# Time:                        03:49:31   Log-Likelihood:                -2257.3
# No. Observations:                 853   AIC:                             4547.
# Df Residuals:                     837   BIC:                             4623.
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                            -34.3324     10.248     -3.350      0.001     -54.447     -14.218
# deathIncrease                  -4.844e+05   7.95e+04     -6.091      0.000    -6.4e+05   -3.28e+05
# hospitalizedCurrently           1.806e+04   2497.664      7.229      0.000    1.32e+04     2.3e+04
# positiveCasesIncrease            -74.2747     86.082     -0.863      0.388    -243.237      94.687
# Population Staying at Home        31.1707      5.622      5.545      0.000      20.136      42.205
# Population Not Staying at Home    34.6035      5.362      6.453      0.000      24.078      45.129
# Number of Trips                    2.2606      4.633      0.488      0.626      -6.833      11.354
# Number of Trips <1                -2.9867      4.811     -0.621      0.535     -12.431       6.457
# Number of Trips 1-3               -5.4431      5.062     -1.075      0.283     -15.378       4.492
# Number of Trips 3-5               -7.8142      6.393     -1.222      0.222     -20.362       4.734
# Number of Trips 5-10               6.9993      6.282      1.114      0.266      -5.331      19.329
# Number of Trips 10-25             -4.9471      4.739     -1.044      0.297     -14.249       4.355
# Number of Trips 25-50            -16.4955      6.712     -2.457      0.014     -29.671      -3.320
# Number of Trips 50-100             7.4661      9.161      0.815      0.415     -10.516      25.448
# Number of Trips 100-250          -46.2758     18.712     -2.473      0.014     -83.004      -9.548
# Number of Trips 250-500          214.0388     54.141      3.953      0.000     107.771     320.307
# Number of Trips >=500           -142.2813     50.093     -2.840      0.005    -240.604     -43.958
# ==============================================================================
# Omnibus:                        4.738   Durbin-Watson:                   1.338
# Prob(Omnibus):                  0.094   Jarque-Bera (JB):                4.792
# Skew:                           0.132   Prob(JB):                       0.0911
# Kurtosis:                       3.255   Cond. No.                     2.09e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.55e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.26915543278359677
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Anxiety_Score   R-squared:                       0.290
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     22.78
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           1.25e-52
# Time:                        03:49:31   Log-Likelihood:                -2322.5
# No. Observations:                 853   AIC:                             4677.
# Df Residuals:                     837   BIC:                             4753.
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                            -20.2536     11.062     -1.831      0.067     -41.966       1.459
# deathIncrease                  -4.634e+05   8.58e+04     -5.399      0.000   -6.32e+05   -2.95e+05
# hospitalizedCurrently           1.796e+04   2696.122      6.662      0.000    1.27e+04    2.33e+04
# positiveCasesIncrease             -9.3399     92.922     -0.101      0.920    -191.727     173.047
# Population Staying at Home        41.9612      6.068      6.915      0.000      30.050      53.872
# Population Not Staying at Home    24.0901      5.789      4.162      0.000      12.728      35.452
# Number of Trips                    6.2370      5.001      1.247      0.213      -3.579      16.053
# Number of Trips <1                -9.6755      5.194     -1.863      0.063     -19.870       0.519
# Number of Trips 1-3               -8.1210      5.464     -1.486      0.138     -18.845       2.603
# Number of Trips 3-5              -10.1429      6.901     -1.470      0.142     -23.688       3.402
# Number of Trips 5-10               2.8269      6.781      0.417      0.677     -10.483      16.137
# Number of Trips 10-25             -6.0202      5.116     -1.177      0.240     -16.062       4.021
# Number of Trips 25-50            -16.4855      7.246     -2.275      0.023     -30.707      -2.264
# Number of Trips 50-100             2.7190      9.889      0.275      0.783     -16.692      22.130
# Number of Trips 100-250          -52.4080     20.199     -2.595      0.010     -92.055     -12.761
# Number of Trips 250-500          222.5931     58.443      3.809      0.000     107.881     337.305
# Number of Trips >=500           -119.0489     54.073     -2.202      0.028    -225.184     -12.913
# ==============================================================================
# Omnibus:                        6.395   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                6.617
# Skew:                           0.159   Prob(JB):                       0.0366
# Kurtosis:                       3.292   Cond. No.                     2.09e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.55e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.2898593312090957

# %% [markdown]
# ### All Data - Top 6 Predictors

# %%
# Multiple Linear Regression
# All Data - top 6 predictors

all_data = data.copy()
feature_data = all_data.drop(['death', 'positiveTestsViral', 'positiveTestsViralIncrease',
                              'positivityRate', 'positiveCasesViral'],
                               axis= 1)
predictors = ['deathIncrease', 'hospitalizedCurrently', 
              'Population Staying at Home',
              'Number of Trips 100-250', 'Number of Trips 250-500',
              'Number of Trips >=500']
multiple_linear_regression(feature_data, predictors, responses)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Mix_Score   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                  0.212
# Method:                 Least Squares   F-statistic:                     39.23
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           3.51e-42
# Time:                        03:49:31   Log-Likelihood:                -2396.3
# No. Observations:                 853   AIC:                             4807.
# Df Residuals:                     846   BIC:                             4840.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         30.1004      1.253     24.019      0.000      27.641      32.560
# deathIncrease                -6.6e+05   8.25e+04     -8.005      0.000   -8.22e+05   -4.98e+05
# hospitalizedCurrently       2.328e+04   2656.850      8.763      0.000    1.81e+04    2.85e+04
# Population Staying at Home    14.0800      2.346      6.001      0.000       9.475      18.685
# Number of Trips 100-250      -73.6455      9.989     -7.373      0.000     -93.251     -54.040
# Number of Trips 250-500      344.7118     53.638      6.427      0.000     239.432     449.991
# Number of Trips >=500       -297.8441     57.289     -5.199      0.000    -410.289    -185.399
# ==============================================================================
# Omnibus:                        3.691   Durbin-Watson:                   1.113
# Prob(Omnibus):                  0.158   Jarque-Bera (JB):                4.282
# Skew:                           0.001   Prob(JB):                        0.118
# Kurtosis:                       3.347   Cond. No.                     6.65e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.65e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0.21765379409075392
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Depression_Score   R-squared:                       0.186
# Model:                            OLS   Adj. R-squared:                  0.180
# Method:                 Least Squares   F-statistic:                     32.22
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           4.95e-35
# Time:                        03:49:31   Log-Likelihood:                -2303.2
# No. Observations:                 853   AIC:                             4620.
# Df Residuals:                     846   BIC:                             4654.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         25.2161      1.124     22.442      0.000      23.011      27.422
# deathIncrease              -6.055e+05   7.39e+04     -8.190      0.000   -7.51e+05    -4.6e+05
# hospitalizedCurrently       2.174e+04   2382.146      9.125      0.000    1.71e+04    2.64e+04
# Population Staying at Home    -0.1738      2.104     -0.083      0.934      -4.303       3.955
# Number of Trips 100-250      -62.4980      8.956     -6.978      0.000     -80.077     -44.919
# Number of Trips 250-500      313.2018     48.092      6.513      0.000     218.808     407.596
# Number of Trips >=500       -223.3733     51.366     -4.349      0.000    -324.192    -122.554
# ==============================================================================
# Omnibus:                        3.200   Durbin-Watson:                   1.193
# Prob(Omnibus):                  0.202   Jarque-Bera (JB):                3.046
# Skew:                           0.124   Prob(JB):                        0.218
# Kurtosis:                       3.155   Cond. No.                     6.65e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.65e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0.18601093853590955
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Anxiety_Score   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.203
# Method:                 Least Squares   F-statistic:                     37.15
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           4.35e-40
# Time:                        03:49:31   Log-Likelihood:                -2368.7
# No. Observations:                 853   AIC:                             4751.
# Df Residuals:                     846   BIC:                             4785.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         24.3399      1.213     20.061      0.000      21.958      26.721
# deathIncrease              -5.883e+05   7.98e+04     -7.370      0.000   -7.45e+05   -4.32e+05
# hospitalizedCurrently       2.008e+04   2572.327      7.804      0.000     1.5e+04    2.51e+04
# Population Staying at Home    16.0240      2.272      7.054      0.000      11.566      20.483
# Number of Trips 100-250      -68.4946      9.671     -7.082      0.000     -87.477     -49.512
# Number of Trips 250-500      330.6887     51.932      6.368      0.000     228.758     432.619
# Number of Trips >=500       -268.1655     55.467     -4.835      0.000    -377.034    -159.297
# ==============================================================================
# Omnibus:                        2.075   Durbin-Watson:                   1.126
# Prob(Omnibus):                  0.354   Jarque-Bera (JB):                2.111
# Skew:                           0.005   Prob(JB):                        0.348
# Kurtosis:                       3.243   Cond. No.                     6.65e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.65e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0.20852977188736754

# %% [markdown]
# ### All Data - Rows with positivityRate

# %%
# Multiple Linear Regression
# All Data - rows with positivity rate

all_data = data.copy()
feature_data = all_data.drop([],
                               axis= 1)
feature_data = feature_data.dropna()
predictors = feature_data.columns[5:]
multiple_linear_regression(feature_data, predictors, responses)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Mix_Score   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.363
# Method:                 Least Squares   F-statistic:                     8.726
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           1.87e-19
# Time:                        03:49:31   Log-Likelihood:                -679.59
# No. Observations:                 272   AIC:                             1401.
# Df Residuals:                     251   BIC:                             1477.
# Df Model:                          20
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             30.8444     33.300      0.926      0.355     -34.739      96.428
# deathIncrease                  -2.538e+05   1.55e+05     -1.641      0.102   -5.58e+05    5.09e+04
# death                           9106.4648   1619.275      5.624      0.000    5917.367    1.23e+04
# hospitalizedCurrently           1.174e+04   5748.575      2.042      0.042     417.337    2.31e+04
# positivityRate                  2.144e+06   1.27e+06      1.686      0.093    -3.6e+05    4.65e+06
# positiveTestsViralIncrease      6335.0640   3226.328      1.964      0.051     -19.060    1.27e+04
# positiveTestsViral              -214.6157     50.520     -4.248      0.000    -314.113    -115.118
# positiveCasesIncrease           -369.2048    210.594     -1.753      0.081    -783.960      45.551
# positiveCasesViral                 7.6771      3.433      2.236      0.026       0.915      14.439
# Population Staying at Home        17.4913     18.685      0.936      0.350     -19.309      54.291
# Population Not Staying at Home     3.8822     15.555      0.250      0.803     -26.753      34.517
# Number of Trips                  -16.9032      7.616     -2.219      0.027     -31.903      -1.903
# Number of Trips <1                16.1243      8.108      1.989      0.048       0.155      32.093
# Number of Trips 1-3                7.8863      8.754      0.901      0.369      -9.355      25.128
# Number of Trips 3-5               30.8098     14.725      2.092      0.037       1.810      59.810
# Number of Trips 5-10               5.3636     11.483      0.467      0.641     -17.251      27.978
# Number of Trips 10-25             26.6623      8.064      3.306      0.001      10.780      42.545
# Number of Trips 25-50             -5.1627     11.759     -0.439      0.661     -28.322      17.996
# Number of Trips 50-100             8.7960     18.627      0.472      0.637     -27.888      45.480
# Number of Trips 100-250           53.9326     37.413      1.442      0.151     -19.751     127.616
# Number of Trips 250-500          283.4540     97.659      2.902      0.004      91.118     475.790
# Number of Trips >=500           -444.7720    101.110     -4.399      0.000    -643.903    -245.641
# ==============================================================================
# Omnibus:                       10.529   Durbin-Watson:                   1.603
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               10.665
# Skew:                           0.445   Prob(JB):                      0.00483
# Kurtosis:                       3.386   Cond. No.                     2.01e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.35e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.4098697249872616
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Depression_Score   R-squared:                       0.375
# Model:                            OLS   Adj. R-squared:                  0.325
# Method:                 Least Squares   F-statistic:                     7.530
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           1.21e-16
# Time:                        03:49:31   Log-Likelihood:                -649.95
# No. Observations:                 272   AIC:                             1342.
# Df Residuals:                     251   BIC:                             1418.
# Df Model:                          20
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             50.7306     29.863      1.699      0.091      -8.083     109.544
# deathIncrease                  -2.151e+05   1.39e+05     -1.551      0.122   -4.88e+05    5.81e+04
# death                           7589.0549   1452.129      5.226      0.000    4729.145    1.04e+04
# hospitalizedCurrently           1.011e+04   5155.190      1.961      0.051     -42.981    2.03e+04
# positivityRate                   1.55e+06   1.14e+06      1.359      0.175   -6.96e+05     3.8e+06
# positiveTestsViralIncrease      6580.1925   2893.297      2.274      0.024     881.959    1.23e+04
# positiveTestsViral              -217.1161     45.305     -4.792      0.000    -306.343    -127.889
# positiveCasesIncrease           -441.2473    188.855     -2.336      0.020    -813.191     -69.304
# positiveCasesViral                 9.3384      3.079      3.033      0.003       3.274      15.402
# Population Staying at Home       -13.9327     16.757     -0.831      0.406     -46.934      19.069
# Population Not Staying at Home    -4.7370     13.949     -0.340      0.734     -32.210      22.736
# Number of Trips                  -14.4411      6.830     -2.114      0.035     -27.893      -0.989
# Number of Trips <1                16.1315      7.271      2.219      0.027       1.811      30.452
# Number of Trips 1-3                5.6363      7.851      0.718      0.473      -9.825      21.098
# Number of Trips 3-5               25.5950     13.205      1.938      0.054      -0.412      51.602
# Number of Trips 5-10               2.2393     10.297      0.217      0.828     -18.041      22.520
# Number of Trips 10-25             20.3383      7.232      2.812      0.005       6.095      34.581
# Number of Trips 25-50             -8.2307     10.545     -0.781      0.436     -28.999      12.538
# Number of Trips 50-100             8.1774     16.704      0.490      0.625     -24.720      41.075
# Number of Trips 100-250           47.7477     33.551      1.423      0.156     -18.330     113.826
# Number of Trips 250-500          204.8884     87.578      2.339      0.020      32.406     377.371
# Number of Trips >=500           -336.9661     90.673     -3.716      0.000    -515.542    -158.390
# ==============================================================================
# Omnibus:                        8.103   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):                8.281
# Skew:                           0.346   Prob(JB):                       0.0159
# Kurtosis:                       3.502   Cond. No.                     2.01e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.35e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.37432140257663205
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Anxiety_Score   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.304
# Method:                 Least Squares   F-statistic:                     6.916
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           3.71e-15
# Time:                        03:49:31   Log-Likelihood:                -696.43
# No. Observations:                 272   AIC:                             1435.
# Df Residuals:                     251   BIC:                             1511.
# Df Model:                          20
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             18.0710     35.428      0.510      0.610     -51.702      87.844
# deathIncrease                  -2.057e+05   1.65e+05     -1.250      0.212    -5.3e+05    1.18e+05
# death                           7497.5960   1722.725      4.352      0.000    4104.759    1.09e+04
# hospitalizedCurrently           1.036e+04   6115.830      1.694      0.091   -1683.815    2.24e+04
# positivityRate                  6.678e+05   1.35e+06      0.494      0.622      -2e+06    3.33e+06
# positiveTestsViralIncrease      5314.1812   3432.446      1.548      0.123   -1445.885    1.21e+04
# positiveTestsViral              -195.1553     53.748     -3.631      0.000    -301.009     -89.301
# positiveCasesIncrease           -246.1170    224.048     -1.099      0.273    -687.370     195.136
# positiveCasesViral                 7.2332      3.653      1.980      0.049       0.039      14.427
# Population Staying at Home        22.2619     19.879      1.120      0.264     -16.889      61.413
# Population Not Staying at Home     6.1779     16.549      0.373      0.709     -26.414      38.770
# Number of Trips                  -10.9046      8.103     -1.346      0.180     -26.863       5.054
# Number of Trips <1                 9.6336      8.626      1.117      0.265      -7.356      26.623
# Number of Trips 1-3                3.2027      9.314      0.344      0.731     -15.140      21.546
# Number of Trips 3-5               19.4557     15.666      1.242      0.215     -11.397      50.308
# Number of Trips 5-10               4.0237     12.216      0.329      0.742     -20.036      28.083
# Number of Trips 10-25             20.0769      8.580      2.340      0.020       3.180      36.974
# Number of Trips 25-50             -5.4293     12.510     -0.434      0.665     -30.068      19.209
# Number of Trips 50-100             4.0006     19.817      0.202      0.840     -35.027      43.028
# Number of Trips 100-250           45.2025     39.803      1.136      0.257     -33.189     123.594
# Number of Trips 250-500          227.4662    103.898      2.189      0.029      22.843     432.089
# Number of Trips >=500           -338.5379    107.569     -3.147      0.002    -550.391    -126.685
# ==============================================================================
# Omnibus:                        9.857   Durbin-Watson:                   1.470
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               10.028
# Skew:                           0.412   Prob(JB):                      0.00665
# Kurtosis:                       3.452   Cond. No.                     2.01e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.35e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.35361040681431744

# %% [markdown]
# ### Run on New England data

# %%
# Multiple Linear Regression
# New England
new_england = data.copy().loc[data["State"].isin(['MA', 'ME', 'VT', 'NH', 'CT', "RI"])].reset_index(drop=True)

ignore_predictors = ['positiveTestsViral', 'positiveCasesViral',]
ignore_predictors = ['death','positivityRate', 'positiveTestsViralIncrease', 
                     'positiveTestsViral', 'positiveCasesViral']
predictors = [item for item in list(data.columns[5:]) if item not in ignore_predictors]
multiple_linear_regression(new_england, predictors, responses)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Mix_Score   R-squared:                       0.473
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     5.504
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           8.26e-08
# Time:                        03:49:31   Log-Likelihood:                -262.72
# No. Observations:                 108   AIC:                             557.4
# Df Residuals:                      92   BIC:                             600.4
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                           -451.6410    190.015     -2.377      0.020    -829.027     -74.255
# deathIncrease                   3.187e+04   2.41e+05      0.132      0.895   -4.46e+05     5.1e+05
# hospitalizedCurrently           -203.6241   1.14e+04     -0.018      0.986   -2.28e+04    2.24e+04
# positiveCasesIncrease            155.2307    242.296      0.641      0.523    -325.990     636.451
# Population Staying at Home       286.4014    102.465      2.795      0.006      82.897     489.905
# Population Not Staying at Home   224.1634     87.383      2.565      0.012      50.612     397.714
# Number of Trips                  -24.1944     33.336     -0.726      0.470     -90.402      42.013
# Number of Trips <1                27.7232     35.340      0.784      0.435     -42.465      97.912
# Number of Trips 1-3               13.2458     31.902      0.415      0.679     -50.114      76.606
# Number of Trips 3-5               20.8076     45.569      0.457      0.649     -69.696     111.311
# Number of Trips 5-10              88.4894     36.170      2.446      0.016      16.653     160.326
# Number of Trips 10-25            -43.1556     35.338     -1.221      0.225    -113.339      27.028
# Number of Trips 25-50            105.4807     52.617      2.005      0.048       0.979     209.982
# Number of Trips 50-100            17.4887     32.837      0.533      0.596     -47.728      82.705
# Number of Trips 100-250           97.4964    105.513      0.924      0.358    -112.061     307.054
# Number of Trips 250-500          -38.5213    477.970     -0.081      0.936    -987.812     910.769
# Number of Trips >=500           -313.2493    185.644     -1.687      0.095    -681.955      55.456
# ==============================================================================
# Omnibus:                        1.120   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.571   Jarque-Bera (JB):                1.195
# Skew:                           0.180   Prob(JB):                        0.550
# Kurtosis:                       2.632   Cond. No.                     1.98e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.59e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.4739668994578703
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Depression_Score   R-squared:                       0.206
# Model:                            OLS   Adj. R-squared:                  0.076
# Method:                 Least Squares   F-statistic:                     1.588
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):             0.0923
# Time:                        03:49:31   Log-Likelihood:                -259.15
# No. Observations:                 108   AIC:                             550.3
# Df Residuals:                      92   BIC:                             593.2
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                           -323.3619    183.844     -1.759      0.082    -688.491      41.767
# deathIncrease                  -4.049e+04   2.33e+05     -0.174      0.862   -5.03e+05    4.22e+05
# hospitalizedCurrently           -359.1466    1.1e+04     -0.033      0.974   -2.23e+04    2.15e+04
# positiveCasesIncrease            151.7472    234.427      0.647      0.519    -313.844     617.339
# Population Staying at Home       189.3359     99.137      1.910      0.059      -7.559     386.231
# Population Not Staying at Home   161.8640     84.545      1.915      0.059      -6.050     329.778
# Number of Trips                  -22.1201     32.253     -0.686      0.495     -86.177      41.937
# Number of Trips <1                27.0149     34.192      0.790      0.432     -40.894      94.924
# Number of Trips 1-3               19.6428     30.866      0.636      0.526     -41.660      80.945
# Number of Trips 3-5                8.5733     44.089      0.194      0.846     -78.991      96.138
# Number of Trips 5-10              66.5976     34.995      1.903      0.060      -2.906     136.101
# Number of Trips 10-25            -25.4092     34.190     -0.743      0.459     -93.313      42.495
# Number of Trips 25-50             80.9114     50.908      1.589      0.115     -20.196     182.019
# Number of Trips 50-100            13.1284     31.770      0.413      0.680     -49.970      76.227
# Number of Trips 100-250          115.2147    102.086      1.129      0.262     -87.537     317.967
# Number of Trips 250-500          -84.7523    462.447     -0.183      0.855   -1003.212     833.707
# Number of Trips >=500           -243.0417    179.615     -1.353      0.179    -599.773     113.689
# ==============================================================================
# Omnibus:                        1.766   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.414   Jarque-Bera (JB):                1.445
# Skew:                           0.281   Prob(JB):                        0.486
# Kurtosis:                       3.069   Cond. No.                     1.98e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.59e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.2070678335304691
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Anxiety_Score   R-squared:                       0.469
# Model:                            OLS   Adj. R-squared:                  0.383
# Method:                 Least Squares   F-statistic:                     5.420
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           1.10e-07
# Time:                        03:49:31   Log-Likelihood:                -262.14
# No. Observations:                 108   AIC:                             556.3
# Df Residuals:                      92   BIC:                             599.2
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                           -365.0898    189.004     -1.932      0.056    -740.468      10.289
# deathIncrease                   4.679e+04   2.39e+05      0.195      0.846   -4.29e+05    5.22e+05
# hospitalizedCurrently          -2180.2973   1.13e+04     -0.192      0.848   -2.47e+04    2.03e+04
# positiveCasesIncrease             78.4424    241.007      0.325      0.746    -400.218     557.103
# Population Staying at Home       240.4745    101.920      2.359      0.020      38.053     442.896
# Population Not Staying at Home   179.9416     86.919      2.070      0.041       7.314     352.569
# Number of Trips                  -21.0979     33.158     -0.636      0.526     -86.953      44.758
# Number of Trips <1                23.3321     35.152      0.664      0.509     -46.483      93.147
# Number of Trips 1-3               10.4533     31.732      0.329      0.743     -52.570      73.476
# Number of Trips 3-5               27.1826     45.327      0.600      0.550     -62.840     117.205
# Number of Trips 5-10              81.6675     35.977      2.270      0.026      10.213     153.122
# Number of Trips 10-25            -49.7037     35.150     -1.414      0.161    -119.514      20.106
# Number of Trips 25-50             99.3695     52.337      1.899      0.061      -4.576     203.315
# Number of Trips 50-100            19.8474     32.662      0.608      0.545     -45.022      84.717
# Number of Trips 100-250           87.1312    104.952      0.830      0.409    -121.312     295.574
# Number of Trips 250-500           35.2051    475.428      0.074      0.941    -909.035     979.446
# Number of Trips >=500           -355.5829    184.657     -1.926      0.057    -722.327      11.162
# ==============================================================================
# Omnibus:                        1.930   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.381   Jarque-Bera (JB):                1.856
# Skew:                           0.315   Prob(JB):                        0.395
# Kurtosis:                       2.875   Cond. No.                     1.98e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.59e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.46802422642955377

# %% [markdown]
# ### New England - Top 3 Predictors

# %%
# Multiple Linear Regression
# New England - top 3 predictors
new_england = data.copy().loc[data["State"].isin(['MA', 'ME', 'VT', 'NH', 'CT', "RI"])].reset_index(drop=True)
new_england = new_england.dropna()

predictors = ['death', 'positivityRate', 'positiveCasesViral']
multiple_linear_regression(new_england, predictors, responses)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Mix_Score   R-squared:                       0.372
# Model:                            OLS   Adj. R-squared:                  0.332
# Method:                 Least Squares   F-statistic:                     9.292
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           6.19e-05
# Time:                        03:49:31   Log-Likelihood:                -132.75
# No. Observations:                  51   AIC:                             273.5
# Df Residuals:                      47   BIC:                             281.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 28.9772      2.014     14.391      0.000      24.926      33.028
# death               2623.8317   2247.444      1.167      0.249   -1897.443    7145.106
# positivityRate      7.406e+06   3.52e+06      2.105      0.041    3.27e+05    1.45e+07
# positiveCasesViral    11.3114      3.301      3.426      0.001       4.670      17.953
# ==============================================================================
# Omnibus:                        7.839   Durbin-Watson:                   1.535
# Prob(Omnibus):                  0.020   Jarque-Bera (JB):                6.910
# Skew:                           0.777   Prob(JB):                       0.0316
# Kurtosis:                       3.915   Cond. No.                     7.58e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.36e-13. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.3722873533346017
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Depression_Score   R-squared:                       0.171
# Model:                            OLS   Adj. R-squared:                  0.118
# Method:                 Least Squares   F-statistic:                     3.225
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):             0.0308
# Time:                        03:49:31   Log-Likelihood:                -120.47
# No. Observations:                  51   AIC:                             248.9
# Df Residuals:                      47   BIC:                             256.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 20.3123      1.583     12.833      0.000      17.128      23.497
# death                848.6988   1766.634      0.480      0.633   -2705.310    4402.708
# positivityRate      2.374e+06   2.77e+06      0.858      0.395   -3.19e+06    7.94e+06
# positiveCasesViral     5.7382      2.595      2.211      0.032       0.517      10.959
# ==============================================================================
# Omnibus:                        3.882   Durbin-Watson:                   1.819
# Prob(Omnibus):                  0.144   Jarque-Bera (JB):                3.097
# Skew:                           0.334   Prob(JB):                        0.213
# Kurtosis:                       4.006   Cond. No.                     7.58e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.36e-13. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.170695007183712
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Anxiety_Score   R-squared:                       0.374
# Model:                            OLS   Adj. R-squared:                  0.334
# Method:                 Least Squares   F-statistic:                     9.345
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           5.90e-05
# Time:                        03:49:31   Log-Likelihood:                -133.42
# No. Observations:                  51   AIC:                             274.8
# Df Residuals:                      47   BIC:                             282.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 24.8964      2.040     12.201      0.000      20.792      29.001
# death               2323.3856   2277.404      1.020      0.313   -2258.161    6904.932
# positivityRate      7.695e+06   3.57e+06      2.158      0.036    5.22e+05    1.49e+07
# positiveCasesViral    11.6653      3.345      3.487      0.001       4.935      18.395
# ==============================================================================
# Omnibus:                       15.271   Durbin-Watson:                   1.410
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.928
# Skew:                           1.148   Prob(JB):                     0.000128
# Kurtosis:                       4.778   Cond. No.                     7.58e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.36e-13. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 0.37363565305449

# %% [markdown]
# ## Single Linear Regression

# %%
def single_linear_regression(data, states, predictors, responses):
    final = {}
    for state in states:
        for predictor in predictors:
            for response in responses:
                # get state data
                state_data = data.copy().loc[data['State'] == state].reset_index(drop=True)
                X = state_data.loc[:,predictor] # feature columns
                y = state_data.loc[:,responses] # label column
                X_reshaped = X.to_numpy().reshape(-1, 1)

                ## Linear Regression ##
                regr = linear_model.LinearRegression()
                lm = regr.fit(X_reshaped, y) # train on training data
                score = regr.score(X_reshaped, y)
                
                # saves best r^2 and corresponding feature
                if not response in final:
                    final[response] = {}
                if state in final[response]:
                    if score > final[response][state][1]:
                        final[response][state] = [predictor, score]
                else:
                    final[response][state] = [predictor, score]

                if state_data.shape[0] == 0:
                    continue
    return final

# %%
# Single Linear Regression
states = data['State'].unique()
ignore_predictors = ['positivityRate','positiveTestsViral', 'positiveTestsViralIncrease']
predictors = [item for item in list(data.columns[5:]) if item not in ignore_predictors]
final_slr = single_linear_regression(data, states, predictors, responses)
with open("final_slr.json", "w") as outfile:  
        json.dump(final_slr, outfile)

# %%
# final result dictionary
'''
final_slr: 
{
Mix_Score:{state:['bestFeature', R^2]},
Depression_Score:{state:['bestFeature', R^2]},
Anxiety_Score:{state:['bestFeature', R^2])
}
'''

final_slr
# Out:
# {'Mix_Score': {'AL': ['hospitalizedCurrently', 0.5405792069032893],
#   'AK': ['positiveCasesIncrease', 0.1724416479921368],
#   'AZ': ['positiveCasesIncrease', 0.5672884929211565],
#   'AR': ['Number of Trips 10-25', 0.1742809206122338],
#   'CA': ['positiveCasesIncrease', 0.5282891209378344],
#   'CO': ['Number of Trips 1-3', 0.4418718440086821],
#   'CT': ['Population Not Staying at Home', 0.22249181166150236],
#   'GA': ['Number of Trips 10-25', 0.2136405842834612],
#   'ID': ['Number of Trips 3-5', 0.5099082374408354],
#   'IL': ['Population Not Staying at Home', 0.11137771621762083],
#   'IN': ['Number of Trips 10-25', 0.3444404611035054],
#   'IA': ['death', 0.35139504456437304],
#   'KY': ['Number of Trips', 0.5797903799073492],
#   'LA': ['positiveCasesIncrease', 0.26685844649785906],
#   'ME': ['positiveCasesViral', 0.26635344004797773],
#   'MD': ['positiveCasesIncrease', 0.23104503227851003],
#   'MA': ['Population Not Staying at Home', 0.46830871366156385],
#   'MN': ['Population Staying at Home', 0.2531571994577976],
#   'MO': ['Number of Trips 25-50', 0.215003653554393],
#   'MT': ['Number of Trips 3-5', 0.2807329350800968],
#   'NH': ['Population Staying at Home', 0.1706281146907345],
#   'NJ': ['Number of Trips <1', 0.09256126477076372],
#   'NM': ['Number of Trips 3-5', 0.2800494491036684],
#   'NY': ['Number of Trips 10-25', 0.21220840835364962],
#   'NC': ['Number of Trips 10-25', 0.38033575568367795],
#   'ND': ['Number of Trips 1-3', 0.2235604641562492],
#   'OH': ['positiveCasesViral', 0.37076067209814934],
#   'OK': ['Number of Trips 10-25', 0.46828376019688234],
#   'OR': ['positiveCasesIncrease', 0.4244237608996855],
#   'PA': ['Number of Trips 5-10', 0.25662867825964886],
#   'RI': ['positiveCasesViral', 0.3576030235400746],
#   'SD': ['Population Staying at Home', 0.09187808965132627],
#   'TN': ['Number of Trips 5-10', 0.35834818988414113],
#   'TX': ['hospitalizedCurrently', 0.6422640174247373],
#   'VT': ['Number of Trips >=500', 0.36941200845391026],
#   'VA': ['hospitalizedCurrently', 0.29867099601657265],
#   'WA': ['Number of Trips 1-3', 0.408404290559855],
#   'WV': ['Number of Trips 50-100', 0.0707472209666119],
#   'WI': ['Number of Trips 10-25', 0.576420978904499],
#   'WY': ['Number of Trips 1-3', 0.3909002978762824],
#   'MS': ['Number of Trips 25-50', 0.3267608795246631],
#   'NE': ['Number of Trips', 0.3348517266079683],
#   'NV': ['hospitalizedCurrently', 0.4369925487860132],
#   'UT': ['Number of Trips 1-3', 0.28292519831850177],
#   'DE': ['Number of Trips 50-100', 0.43763971839031046],
#   'DC': ['Number of Trips 25-50', 0.2519489141785616],
#   'SC': ['Number of Trips 25-50', 0.27556933257398075],
#   'FL': ['Number of Trips 10-25', 0.844309317179602],
#   'HI': ['Number of Trips 100-250', 0.3725013827620285],
#   'KS': ['hospitalizedCurrently', 0.8611513954367928]},
#  'Depression_Score': {'AL': ['hospitalizedCurrently', 0.5405792069032893],
#   'AK': ['positiveCasesIncrease', 0.1724416479921368],
#   'AZ': ['positiveCasesIncrease', 0.5672884929211565],
#   'AR': ['Number of Trips 10-25', 0.1742809206122338],
#   'CA': ['positiveCasesIncrease', 0.5282891209378344],
#   'CO': ['Number of Trips 1-3', 0.4418718440086821],
#   'CT': ['Population Not Staying at Home', 0.22249181166150236],
#   'GA': ['Number of Trips 10-25', 0.2136405842834612],
#   'ID': ['Number of Trips 3-5', 0.5099082374408354],
#   'IL': ['Population Not Staying at Home', 0.11137771621762083],
#   'IN': ['Number of Trips 10-25', 0.3444404611035054],
#   'IA': ['death', 0.35139504456437304],
#   'KY': ['Number of Trips', 0.5797903799073492],
#   'LA': ['positiveCasesIncrease', 0.26685844649785906],
#   'ME': ['positiveCasesViral', 0.26635344004797773],
#   'MD': ['positiveCasesIncrease', 0.23104503227851003],
#   'MA': ['Population Not Staying at Home', 0.46830871366156385],
#   'MN': ['Population Staying at Home', 0.2531571994577976],
#   'MO': ['Number of Trips 25-50', 0.215003653554393],
#   'MT': ['Number of Trips 3-5', 0.2807329350800968],
#   'NH': ['Population Staying at Home', 0.1706281146907345],
#   'NJ': ['Number of Trips <1', 0.09256126477076372],
#   'NM': ['Number of Trips 3-5', 0.2800494491036684],
#   'NY': ['Number of Trips 10-25', 0.21220840835364962],
#   'NC': ['Number of Trips 10-25', 0.38033575568367795],
#   'ND': ['Number of Trips 1-3', 0.2235604641562492],
#   'OH': ['positiveCasesViral', 0.37076067209814934],
#   'OK': ['Number of Trips 10-25', 0.46828376019688234],
#   'OR': ['positiveCasesIncrease', 0.4244237608996855],
#   'PA': ['Number of Trips 5-10', 0.25662867825964886],
#   'RI': ['positiveCasesViral', 0.3576030235400746],
#   'SD': ['Population Staying at Home', 0.09187808965132627],
#   'TN': ['Number of Trips 5-10', 0.35834818988414113],
#   'TX': ['hospitalizedCurrently', 0.6422640174247373],
#   'VT': ['Number of Trips >=500', 0.36941200845391026],
#   'VA': ['hospitalizedCurrently', 0.29867099601657265],
#   'WA': ['Number of Trips 1-3', 0.408404290559855],
#   'WV': ['Number of Trips 50-100', 0.0707472209666119],
#   'WI': ['Number of Trips 10-25', 0.576420978904499],
#   'WY': ['Number of Trips 1-3', 0.3909002978762824],
#   'MS': ['Number of Trips 25-50', 0.3267608795246631],
#   'NE': ['Number of Trips', 0.3348517266079683],
#   'NV': ['hospitalizedCurrently', 0.4369925487860132],
#   'UT': ['Number of Trips 1-3', 0.28292519831850177],
#   'DE': ['Number of Trips 50-100', 0.43763971839031046],
#   'DC': ['Number of Trips 25-50', 0.2519489141785616],
#   'SC': ['Number of Trips 25-50', 0.27556933257398075],
#   'FL': ['Number of Trips 10-25', 0.844309317179602],
#   'HI': ['Number of Trips 100-250', 0.3725013827620285],
#   'KS': ['hospitalizedCurrently', 0.8611513954367928]},
#  'Anxiety_Score': {'AL': ['hospitalizedCurrently', 0.5405792069032893],
#   'AK': ['positiveCasesIncrease', 0.1724416479921368],
#   'AZ': ['positiveCasesIncrease', 0.5672884929211565],
#   'AR': ['Number of Trips 10-25', 0.1742809206122338],
#   'CA': ['positiveCasesIncrease', 0.5282891209378344],
#   'CO': ['Number of Trips 1-3', 0.4418718440086821],
#   'CT': ['Population Not Staying at Home', 0.22249181166150236],
#   'GA': ['Number of Trips 10-25', 0.2136405842834612],
#   'ID': ['Number of Trips 3-5', 0.5099082374408354],
#   'IL': ['Population Not Staying at Home', 0.11137771621762083],
#   'IN': ['Number of Trips 10-25', 0.3444404611035054],
#   'IA': ['death', 0.35139504456437304],
#   'KY': ['Number of Trips', 0.5797903799073492],
#   'LA': ['positiveCasesIncrease', 0.26685844649785906],
#   'ME': ['positiveCasesViral', 0.26635344004797773],
#   'MD': ['positiveCasesIncrease', 0.23104503227851003],
#   'MA': ['Population Not Staying at Home', 0.46830871366156385],
#   'MN': ['Population Staying at Home', 0.2531571994577976],
#   'MO': ['Number of Trips 25-50', 0.215003653554393],
#   'MT': ['Number of Trips 3-5', 0.2807329350800968],
#   'NH': ['Population Staying at Home', 0.1706281146907345],
#   'NJ': ['Number of Trips <1', 0.09256126477076372],
#   'NM': ['Number of Trips 3-5', 0.2800494491036684],
#   'NY': ['Number of Trips 10-25', 0.21220840835364962],
#   'NC': ['Number of Trips 10-25', 0.38033575568367795],
#   'ND': ['Number of Trips 1-3', 0.2235604641562492],
#   'OH': ['positiveCasesViral', 0.37076067209814934],
#   'OK': ['Number of Trips 10-25', 0.46828376019688234],
#   'OR': ['positiveCasesIncrease', 0.4244237608996855],
#   'PA': ['Number of Trips 5-10', 0.25662867825964886],
#   'RI': ['positiveCasesViral', 0.3576030235400746],
#   'SD': ['Population Staying at Home', 0.09187808965132627],
#   'TN': ['Number of Trips 5-10', 0.35834818988414113],
#   'TX': ['hospitalizedCurrently', 0.6422640174247373],
#   'VT': ['Number of Trips >=500', 0.36941200845391026],
#   'VA': ['hospitalizedCurrently', 0.29867099601657265],
#   'WA': ['Number of Trips 1-3', 0.408404290559855],
#   'WV': ['Number of Trips 50-100', 0.0707472209666119],
#   'WI': ['Number of Trips 10-25', 0.576420978904499],
#   'WY': ['Number of Trips 1-3', 0.3909002978762824],
#   'MS': ['Number of Trips 25-50', 0.3267608795246631],
#   'NE': ['Number of Trips', 0.3348517266079683],
#   'NV': ['hospitalizedCurrently', 0.4369925487860132],
#   'UT': ['Number of Trips 1-3', 0.28292519831850177],
#   'DE': ['Number of Trips 50-100', 0.43763971839031046],
#   'DC': ['Number of Trips 25-50', 0.2519489141785616],
#   'SC': ['Number of Trips 25-50', 0.27556933257398075],
#   'FL': ['Number of Trips 10-25', 0.844309317179602],
#   'HI': ['Number of Trips 100-250', 0.3725013827620285],
#   'KS': ['hospitalizedCurrently', 0.8611513954367928]}}
